# %%
from ipyleaflet import Map, Circle
import requests
import json
import pandas as pd
import os
from dotenv import load_dotenv

# %%
load_dotenv()
GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")

# %%
def search_by_adress(adress):
  url = f"https://maps.googleapis.com/maps/api/place/textsearch/json?query={adress}&key={GOOGLE_API_KEY}"
  response = requests.get(url)
  data = json.loads(response.text)
  return data

# %%
def make_circle(center, color, radius) -> Circle:
  circle = Circle()
  circle.location = center
  circle.radius = radius
  circle.color = color
  circle.fill_color = color
  return circle

# %%
def get_point_google_response(response):
  return (response["geometry"]["location"]["lat"], response["geometry"]["location"]["lng"])

# %%
def assign_color(score):
    color = [
        {
            "max": 2,
            "color": "yellow"
        },
        {
            "max": 4,
            "color": "orange"
        },
        {
            "max": 11,
            "color": "red"
        },
    ]
    for item in color:
        if score <= item["max"]:
            return item["color"]
    return "gray"

# %%
df = pd.read_excel(r'GEOPORTAL PUNTOS CRITICOS AGOSTO2023 (1) (1).xlsx')
df
# Out:
#     Nº                                              LUGAR DEPARTAMENTO  \
# 0    1           Av. CARLOS IZAGUIRRE /PANAMERICANA NORTE         LIMA
# 1    2                       .Av. ELPACIFICO /TUPAC AMARU         LIMA
# 2    3            Av.TOMAS VALLE /AV. PANAMERICANA NORTE          LIMA
# 3    4                    Av.TOMAS VALLE /AV. TUPAC AMARU         LIMA
# 4    5           AV. CARLOS IZAGUIRRE /ALFREDO MENDIOLA           LIMA
# 5    6                    AV. INDUSTRIAL /AV. ELPACIFICO          LIMA
# 6    7  AV. CHINCHAYSUYO CON AV. HUAMACHUCO REF. PARAD...         LIMA
# 7    8                 AV. CHINCHAYSUYO CON AV. CONTISUYO         LIMA
# 8    9                                Av. 20 de Diciembre         LIMA
# 9   10                                            Calle 1         LIMA
# 10  11                    AV. EL MILAGRO Ñ AAH EL MILAGRO         LIMA
# 11  12  CDRA. 2 DE LA CALLE LAS CASUARINAS DE LA URB. ...         LIMA
# 12  13  AV. BELAUNDE (CRUCE AV. EL RETABLO / AV. UNIVE...         LIMA
# 13  14  AV. GUILLERMO LA FUENTE CDRAS. 1-3 (CRUCE AV. ...         LIMA
# 14  15  AV TRAPICHE (CRUCE AV. CHACRA CERRO / AV. PANA...         LIMA
# 15  16  AV. ALFREDO MENDIOLA ALTURA DEL REAL PLAZA DE PRO         LIMA
# 16  17  AV. ALFREDO MENDIOLA / AV. PROCERES DE HUANDOY...         LIMA
# 17  18   AV  CARABAYLLO (AV 22 ADE AGOSTO - AV EL PARRAL)         LIMA
# 18  19                     AV UNIVERSITARIA CON AV MEXICO         LIMA
# 19  20  AV UNIVERSITARIA (JR LOPEZ ALDANA  - AV  METRO...         LIMA
# 20  21                                       AV. BELAUNDE         LIMA
# 21  22                                           AV. PUNO         LIMA
# 22  23                                            MEGA 80         LIMA
# 23  24      AV. BELAUNDE OESTE CUADRA 4 DISTRITO DE COMAS         LIMA
# 24  25                  AV TUPAC AMARU FRENTE A PLAZA VEA         LIMA
# 25  26                   JR CARLOS MORE NRO 602 AÑO NUEVO         LIMA
# 26  27               PUENTE DEL PARADERO LA PASCANA COMAS         LIMA
# 27  28  AV. REVOLUCION / AV. MARIA PARADO DE BELLIDO 5...         LIMA
# 28  29  AV. REVOLUCION / AV. JULIO C. TELLO (MERCADO E...         LIMA
# 29  30                     ALAMEDA YHONNY OROSCO 3RA ZONA         LIMA
#
#    PROVINCIA       DISTRITO   DIVPOL COMISARIA DE LA JURISDICCION  \
# 0       LIMA  INDEPENDENCIA  NORTE 2                INDEPENDENCIA
# 1       LIMA  INDEPENDENCIA  NORTE 2                INDEPENDENCIA
# 2       LIMA  INDEPENDENCIA  NORTE 2                INDEPENDENCIA
# 3       LIMA  INDEPENDENCIA  NORTE 2                INDEPENDENCIA
# 4       LIMA  INDEPENDENCIA  NORTE 2                INDEPENDENCIA
# 5       LIMA  INDEPENDENCIA  NORTE 2                INDEPENDENCIA
# 6       LIMA           IND.  NORTE 2                TAHUANTINSUYO
# 7       LIMA           IND.  NORTE 2                TAHUANTINSUYO
# 8       LIMA  INDEPENDENCIA  NORTE 2                   CPNP PAYET
# 9       LIMA  INDEPENDENCIA  NORTE 2                   CPNP PAYET
# 10      LIMA  INDEPENDENCIA  NORTE 2                 LA UNIFICADA
# 11      LIMA  INDEPENDENCIA  NORTE 2                 LA UNIFICADA
# 12      LIMA          COMAS  NORTE 2                SANTA LUZMILA
# 13      LIMA          COMAS  NORTE 2                SANTA LUZMILA
# 14      LIMA          COMAS  NORTE 2                SANTA LUZMILA
# 15      LIMA            SMP  NORTE 2                SANTA LUZMILA
# 16      LIMA            SMP  NORTE 2                SANTA LUZMILA
# 17      LIMA          COMAS  NORTE 2                UNIVERSITARIA
# 18      LIMA          COMAS  NORTE 2                UNIVERSITARIA
# 19      LIMA          COMAS  NORTE 2                UNIVERSITARIA
# 20      LIMA          COMAS  NORTE 2                  TUPAC AMARU
# 21      LIMA          COMAS  NORTE 2                  TUPAC AMARU
# 22      LIMA          COMAS  NORTE 2                  TUPAC AMARU
# 23      LIMA          COMAS  NORTE 2              CIA. LA PASCANA
# 24      LIMA          COMAS  NORTE 2              CIA. LA PASCANA
# 25      LIMA          COMAS  NORTE 2              CIA. LA PASCANA
# 26      LIMA          COMAS  NORTE 2              CIA. LA PASCANA
# 27      LIMA          COMAS  NORTE 2                 CIA COLLIQUE
# 28      LIMA          COMAS  NORTE 2                 CIA COLLIQUE
# 29      LIMA          COMAS  NORTE 2                 CIA COLLIQUE
#
#                  TIPO DE DELITO  \
# 0             DCP ROBO AGRAVADO
# 1             DCP ROBO AGRAVADO
# 2             DCP ROBO AGRAVADO
# 3             DCP ROBO AGRAVADO
# 4                          DCSP
# 5                          DCSP
# 6            DCP - ROBO - HURTO
# 7            DCP - HURTO - ROBO
# 8                           DCP
# 9                           DCP
# 10                          DCP
# 11                          DCP
# 12               DCP ROBO/HURTO
# 13               DCP ROBO/HURTO
# 14               DCP ROBO/HURTO
# 15               DCP ROBO/HURTO
# 16               DCP ROBO/HURTO
# 17  DELITO CONTRA EL PATRIMONIO
# 18  DELITO CONTRA EL PATRIMONIO
# 19  DELITO CONTRA EL PATRIMONIO
# 20                        D/C/P
# 21                        D/C/P
# 22                        D/C/P
# 23  DELITO CONTRA EL PATRIMONIO
# 24  DELITO CONTRA EL PATRIMONIO
# 25  DELITO CONTRA EL PATRIMONIO
# 26  DELITO CONTRA EL PATRIMONIO
# 27                          DCP
# 28                          DCP
# 29                          DCP
#
#                                             MODALIDAD LUNES MARTES MIERCOLES  \
# 0                   ARREBATO Y COGOTEO A TRANSEUNTE,    NaN      X         X
# 1                          A MANO ARMADA A TRANSEUNTE     X      X         X
# 2                          A MANO ARMADA A TRANSEUNTE     X      X         X
# 3                          A MANO ARMADA A TRANSEUNTE   NaN      X       NaN
# 4                                CONDUCC EST EBRIEDAD     X      X         X
# 5                                CONDUCC EST EBRIEDAD   NaN      X       NaN
# 6                        ARREBATO-LANZA-A MANO ARMADA   NaN    NaN         X
# 7    ARREBATO-LANZA-A MANO ARMADA-COGOTEO-ESTACIONADO   NaN      X         X
# 8                                  VIOLENCIA FAMILIAR     X    NaN       NaN
# 9                                        HURTO Y ROBO   NaN    NaN       NaN
# 10                        ROBO AGRAVADO A MANO ARMADA   NaN    NaN       NaN
# 11                        ROBO AGRAVADO A MANO ARMADA   NaN    NaN       NaN
# 12                        ARREBATO/SUSTRACCION/ARMADO   NaN     X          X
# 13                        ARREBATO/SUSTRACCION/ARMADO     X     X        NaN
# 14                        ARREBATO/SUSTRACCION/ARMADO   NaN     X        NaN
# 15                        ARREBATO/SUSTRACCION/ARMADO     X     X        NaN
# 16                        ARREBATO/SUSTRACCION/ARMADO   NaN     X          X
# 17                                      ROBO AGRAVADO     X    NaN         X
# 18                                      ROBO AGRAVADO   NaN      X         X
# 19                                      ROBO AGRAVADO     X      X         X
# 20  ROBO A TRANSEUNTE, CON ARMA DE FUEGO, USANDO M...     X      X       NaN
# 21  ROBO A TRANSEUNTE, CON ARMA DE FUEGO, USANDO M...     X    NaN       NaN
# 22  ROBO A TRANSEUNTE, CON ARMA DE FUEGO, USANDO M...   NaN    NaN       NaN
# 23                                 ROBO A MANO ARMADA   NaN    NaN       NaN
# 24                            ROBO AGRAVADO EN BANDA    NaN    NaN       NaN
# 25                         ASALTO Y ROBO DE VEHICULOS   NaN    NaN       NaN
# 26                                     ROBO AGRAVADO    NaN    NaN       NaN
# 27                                      ROBO AGRAVADO   NaN      X       NaN
# 28                                               ROBO     X      X         X
# 29                                      ROBO AGRAVADO   NaN    NaN         X
#
#    JUEVES VIERNES SABADO DOMINGO 00,00 a 06,00 06:00 - 12:00 12:00 - 18:00  \
# 0     NaN       X      X       X             X           NaN             X
# 1       X       X      X       X             X             X             X
# 2       X       X      X       X           NaN           NaN             X
# 3       X       X      X       X             X           NaN             X
# 4       X       X      X       X             X             X             X
# 5       X       X      X       X             X             X             X
# 6       X       X    NaN     NaN           NaN             X             X
# 7     NaN       X      X       X           NaN             X             X
# 8     NaN       X      X     NaN             X             X           NaN
# 9     NaN       X    NaN     NaN           NaN             X           NaN
# 10    NaN     NaN    NaN       X           NaN           NaN           NaN
# 11      X     NaN    NaN     NaN           NaN           NaN             X
# 12     X      NaN     X      NaN           NaN           NaN             X
# 13    NaN       X     X      NaN           NaN             X             X
# 14     X        X      X       X             X             X           NaN
# 15     X        X      X     NaN           NaN             X             X
# 16     X      NaN      X       X           NaN             X             X
# 17      X       X    NaN     NaN             X             X             X
# 18      X     NaN    NaN       X           NaN             X             X
# 19      X       X      X       X           NaN             X             X
# 20    NaN       X      X     NaN             X           NaN           NaN
# 21    NaN       X    NaN       X           NaN           NaN             X
# 22    NaN       X    NaN       X           NaN           NaN             X
# 23    NaN     NaN    NaN       X           NaN             X           NaN
# 24      X     NaN    NaN     NaN           NaN           NaN           NaN
# 25    NaN       X    NaN     NaN           NaN           NaN           NaN
# 26    NaN     NaN    NaN       X           NaN           NaN           NaN
# 27      X       X    NaN     NaN           NaN           NaN             X
# 28      X       X      X       X             X             X             X
# 29      X       X    NaN     NaN           NaN           NaN             X
#
#    18:00 - 00:00
# 0              X
# 1              X
# 2              X
# 3              X
# 4              X
# 5              X
# 6            NaN
# 7            NaN
# 8            NaN
# 9              X
# 10             X
# 11           NaN
# 12             X
# 13           NaN
# 14             X
# 15             X
# 16             X
# 17             X
# 18           NaN
# 19             X
# 20             X
# 21             X
# 22           NaN
# 23           NaN
# 24             X
# 25             X
# 26             X
# 27             X
# 28             X
# 29             X

# %%
df = df.fillna(0)
df
# Out:
#     Nº                                              LUGAR DEPARTAMENTO  \
# 0    1           Av. CARLOS IZAGUIRRE /PANAMERICANA NORTE         LIMA
# 1    2                       .Av. ELPACIFICO /TUPAC AMARU         LIMA
# 2    3            Av.TOMAS VALLE /AV. PANAMERICANA NORTE          LIMA
# 3    4                    Av.TOMAS VALLE /AV. TUPAC AMARU         LIMA
# 4    5           AV. CARLOS IZAGUIRRE /ALFREDO MENDIOLA           LIMA
# 5    6                    AV. INDUSTRIAL /AV. ELPACIFICO          LIMA
# 6    7  AV. CHINCHAYSUYO CON AV. HUAMACHUCO REF. PARAD...         LIMA
# 7    8                 AV. CHINCHAYSUYO CON AV. CONTISUYO         LIMA
# 8    9                                Av. 20 de Diciembre         LIMA
# 9   10                                            Calle 1         LIMA
# 10  11                    AV. EL MILAGRO Ñ AAH EL MILAGRO         LIMA
# 11  12  CDRA. 2 DE LA CALLE LAS CASUARINAS DE LA URB. ...         LIMA
# 12  13  AV. BELAUNDE (CRUCE AV. EL RETABLO / AV. UNIVE...         LIMA
# 13  14  AV. GUILLERMO LA FUENTE CDRAS. 1-3 (CRUCE AV. ...         LIMA
# 14  15  AV TRAPICHE (CRUCE AV. CHACRA CERRO / AV. PANA...         LIMA
# 15  16  AV. ALFREDO MENDIOLA ALTURA DEL REAL PLAZA DE PRO         LIMA
# 16  17  AV. ALFREDO MENDIOLA / AV. PROCERES DE HUANDOY...         LIMA
# 17  18   AV  CARABAYLLO (AV 22 ADE AGOSTO - AV EL PARRAL)         LIMA
# 18  19                     AV UNIVERSITARIA CON AV MEXICO         LIMA
# 19  20  AV UNIVERSITARIA (JR LOPEZ ALDANA  - AV  METRO...         LIMA
# 20  21                                       AV. BELAUNDE         LIMA
# 21  22                                           AV. PUNO         LIMA
# 22  23                                            MEGA 80         LIMA
# 23  24      AV. BELAUNDE OESTE CUADRA 4 DISTRITO DE COMAS         LIMA
# 24  25                  AV TUPAC AMARU FRENTE A PLAZA VEA         LIMA
# 25  26                   JR CARLOS MORE NRO 602 AÑO NUEVO         LIMA
# 26  27               PUENTE DEL PARADERO LA PASCANA COMAS         LIMA
# 27  28  AV. REVOLUCION / AV. MARIA PARADO DE BELLIDO 5...         LIMA
# 28  29  AV. REVOLUCION / AV. JULIO C. TELLO (MERCADO E...         LIMA
# 29  30                     ALAMEDA YHONNY OROSCO 3RA ZONA         LIMA
#
#    PROVINCIA       DISTRITO   DIVPOL COMISARIA DE LA JURISDICCION  \
# 0       LIMA  INDEPENDENCIA  NORTE 2                INDEPENDENCIA
# 1       LIMA  INDEPENDENCIA  NORTE 2                INDEPENDENCIA
# 2       LIMA  INDEPENDENCIA  NORTE 2                INDEPENDENCIA
# 3       LIMA  INDEPENDENCIA  NORTE 2                INDEPENDENCIA
# 4       LIMA  INDEPENDENCIA  NORTE 2                INDEPENDENCIA
# 5       LIMA  INDEPENDENCIA  NORTE 2                INDEPENDENCIA
# 6       LIMA           IND.  NORTE 2                TAHUANTINSUYO
# 7       LIMA           IND.  NORTE 2                TAHUANTINSUYO
# 8       LIMA  INDEPENDENCIA  NORTE 2                   CPNP PAYET
# 9       LIMA  INDEPENDENCIA  NORTE 2                   CPNP PAYET
# 10      LIMA  INDEPENDENCIA  NORTE 2                 LA UNIFICADA
# 11      LIMA  INDEPENDENCIA  NORTE 2                 LA UNIFICADA
# 12      LIMA          COMAS  NORTE 2                SANTA LUZMILA
# 13      LIMA          COMAS  NORTE 2                SANTA LUZMILA
# 14      LIMA          COMAS  NORTE 2                SANTA LUZMILA
# 15      LIMA            SMP  NORTE 2                SANTA LUZMILA
# 16      LIMA            SMP  NORTE 2                SANTA LUZMILA
# 17      LIMA          COMAS  NORTE 2                UNIVERSITARIA
# 18      LIMA          COMAS  NORTE 2                UNIVERSITARIA
# 19      LIMA          COMAS  NORTE 2                UNIVERSITARIA
# 20      LIMA          COMAS  NORTE 2                  TUPAC AMARU
# 21      LIMA          COMAS  NORTE 2                  TUPAC AMARU
# 22      LIMA          COMAS  NORTE 2                  TUPAC AMARU
# 23      LIMA          COMAS  NORTE 2              CIA. LA PASCANA
# 24      LIMA          COMAS  NORTE 2              CIA. LA PASCANA
# 25      LIMA          COMAS  NORTE 2              CIA. LA PASCANA
# 26      LIMA          COMAS  NORTE 2              CIA. LA PASCANA
# 27      LIMA          COMAS  NORTE 2                 CIA COLLIQUE
# 28      LIMA          COMAS  NORTE 2                 CIA COLLIQUE
# 29      LIMA          COMAS  NORTE 2                 CIA COLLIQUE
#
#                  TIPO DE DELITO  \
# 0             DCP ROBO AGRAVADO
# 1             DCP ROBO AGRAVADO
# 2             DCP ROBO AGRAVADO
# 3             DCP ROBO AGRAVADO
# 4                          DCSP
# 5                          DCSP
# 6            DCP - ROBO - HURTO
# 7            DCP - HURTO - ROBO
# 8                           DCP
# 9                           DCP
# 10                          DCP
# 11                          DCP
# 12               DCP ROBO/HURTO
# 13               DCP ROBO/HURTO
# 14               DCP ROBO/HURTO
# 15               DCP ROBO/HURTO
# 16               DCP ROBO/HURTO
# 17  DELITO CONTRA EL PATRIMONIO
# 18  DELITO CONTRA EL PATRIMONIO
# 19  DELITO CONTRA EL PATRIMONIO
# 20                        D/C/P
# 21                        D/C/P
# 22                        D/C/P
# 23  DELITO CONTRA EL PATRIMONIO
# 24  DELITO CONTRA EL PATRIMONIO
# 25  DELITO CONTRA EL PATRIMONIO
# 26  DELITO CONTRA EL PATRIMONIO
# 27                          DCP
# 28                          DCP
# 29                          DCP
#
#                                             MODALIDAD LUNES MARTES MIERCOLES  \
# 0                   ARREBATO Y COGOTEO A TRANSEUNTE,      0      X         X
# 1                          A MANO ARMADA A TRANSEUNTE     X      X         X
# 2                          A MANO ARMADA A TRANSEUNTE     X      X         X
# 3                          A MANO ARMADA A TRANSEUNTE     0      X         0
# 4                                CONDUCC EST EBRIEDAD     X      X         X
# 5                                CONDUCC EST EBRIEDAD     0      X         0
# 6                        ARREBATO-LANZA-A MANO ARMADA     0      0         X
# 7    ARREBATO-LANZA-A MANO ARMADA-COGOTEO-ESTACIONADO     0      X         X
# 8                                  VIOLENCIA FAMILIAR     X      0         0
# 9                                        HURTO Y ROBO     0      0         0
# 10                        ROBO AGRAVADO A MANO ARMADA     0      0         0
# 11                        ROBO AGRAVADO A MANO ARMADA     0      0         0
# 12                        ARREBATO/SUSTRACCION/ARMADO     0     X          X
# 13                        ARREBATO/SUSTRACCION/ARMADO     X     X          0
# 14                        ARREBATO/SUSTRACCION/ARMADO     0     X          0
# 15                        ARREBATO/SUSTRACCION/ARMADO     X     X          0
# 16                        ARREBATO/SUSTRACCION/ARMADO     0     X          X
# 17                                      ROBO AGRAVADO     X      0         X
# 18                                      ROBO AGRAVADO     0      X         X
# 19                                      ROBO AGRAVADO     X      X         X
# 20  ROBO A TRANSEUNTE, CON ARMA DE FUEGO, USANDO M...     X      X         0
# 21  ROBO A TRANSEUNTE, CON ARMA DE FUEGO, USANDO M...     X      0         0
# 22  ROBO A TRANSEUNTE, CON ARMA DE FUEGO, USANDO M...     0      0         0
# 23                                 ROBO A MANO ARMADA     0      0         0
# 24                            ROBO AGRAVADO EN BANDA      0      0         0
# 25                         ASALTO Y ROBO DE VEHICULOS     0      0         0
# 26                                     ROBO AGRAVADO      0      0         0
# 27                                      ROBO AGRAVADO     0      X         0
# 28                                               ROBO     X      X         X
# 29                                      ROBO AGRAVADO     0      0         X
#
#    JUEVES VIERNES SABADO DOMINGO 00,00 a 06,00 06:00 - 12:00 12:00 - 18:00  \
# 0       0       X      X       X             X             0             X
# 1       X       X      X       X             X             X             X
# 2       X       X      X       X             0             0             X
# 3       X       X      X       X             X             0             X
# 4       X       X      X       X             X             X             X
# 5       X       X      X       X             X             X             X
# 6       X       X      0       0             0             X             X
# 7       0       X      X       X             0             X             X
# 8       0       X      X       0             X             X             0
# 9       0       X      0       0             0             X             0
# 10      0       0      0       X             0             0             0
# 11      X       0      0       0             0             0             X
# 12     X        0     X        0             0             0             X
# 13      0       X     X        0             0             X             X
# 14     X        X      X       X             X             X             0
# 15     X        X      X       0             0             X             X
# 16     X        0      X       X             0             X             X
# 17      X       X      0       0             X             X             X
# 18      X       0      0       X             0             X             X
# 19      X       X      X       X             0             X             X
# 20      0       X      X       0             X             0             0
# 21      0       X      0       X             0             0             X
# 22      0       X      0       X             0             0             X
# 23      0       0      0       X             0             X             0
# 24      X       0      0       0             0             0             0
# 25      0       X      0       0             0             0             0
# 26      0       0      0       X             0             0             0
# 27      X       X      0       0             0             0             X
# 28      X       X      X       X             X             X             X
# 29      X       X      0       0             0             0             X
#
#    18:00 - 00:00
# 0              X
# 1              X
# 2              X
# 3              X
# 4              X
# 5              X
# 6              0
# 7              0
# 8              0
# 9              X
# 10             X
# 11             0
# 12             X
# 13             0
# 14             X
# 15             X
# 16             X
# 17             X
# 18             0
# 19             X
# 20             X
# 21             X
# 22             0
# 23             0
# 24             X
# 25             X
# 26             X
# 27             X
# 28             X
# 29             X

# %%
df['SUMA_X'] = (df == 'X').sum(axis=1)
df = df[df['DISTRITO'] == 'COMAS']
df = df[["LUGAR", "SUMA_X", "TIPO DE DELITO", "MODALIDAD"]]
df
# Out:
#                                                 LUGAR  SUMA_X  \
# 12  AV. BELAUNDE (CRUCE AV. EL RETABLO / AV. UNIVE...       3
# 13  AV. GUILLERMO LA FUENTE CDRAS. 1-3 (CRUCE AV. ...       4
# 14  AV TRAPICHE (CRUCE AV. CHACRA CERRO / AV. PANA...       6
# 17   AV  CARABAYLLO (AV 22 ADE AGOSTO - AV EL PARRAL)       8
# 18                     AV UNIVERSITARIA CON AV MEXICO       6
# 19  AV UNIVERSITARIA (JR LOPEZ ALDANA  - AV  METRO...      10
# 20                                       AV. BELAUNDE       6
# 21                                           AV. PUNO       5
# 22                                            MEGA 80       3
# 23      AV. BELAUNDE OESTE CUADRA 4 DISTRITO DE COMAS       2
# 24                  AV TUPAC AMARU FRENTE A PLAZA VEA       2
# 25                   JR CARLOS MORE NRO 602 AÑO NUEVO       2
# 26               PUENTE DEL PARADERO LA PASCANA COMAS       2
# 27  AV. REVOLUCION / AV. MARIA PARADO DE BELLIDO 5...       5
# 28  AV. REVOLUCION / AV. JULIO C. TELLO (MERCADO E...      11
# 29                     ALAMEDA YHONNY OROSCO 3RA ZONA       5
#
#                  TIPO DE DELITO  \
# 12               DCP ROBO/HURTO
# 13               DCP ROBO/HURTO
# 14               DCP ROBO/HURTO
# 17  DELITO CONTRA EL PATRIMONIO
# 18  DELITO CONTRA EL PATRIMONIO
# 19  DELITO CONTRA EL PATRIMONIO
# 20                        D/C/P
# 21                        D/C/P
# 22                        D/C/P
# 23  DELITO CONTRA EL PATRIMONIO
# 24  DELITO CONTRA EL PATRIMONIO
# 25  DELITO CONTRA EL PATRIMONIO
# 26  DELITO CONTRA EL PATRIMONIO
# 27                          DCP
# 28                          DCP
# 29                          DCP
#
#                                             MODALIDAD
# 12                        ARREBATO/SUSTRACCION/ARMADO
# 13                        ARREBATO/SUSTRACCION/ARMADO
# 14                        ARREBATO/SUSTRACCION/ARMADO
# 17                                      ROBO AGRAVADO
# 18                                      ROBO AGRAVADO
# 19                                      ROBO AGRAVADO
# 20  ROBO A TRANSEUNTE, CON ARMA DE FUEGO, USANDO M...
# 21  ROBO A TRANSEUNTE, CON ARMA DE FUEGO, USANDO M...
# 22  ROBO A TRANSEUNTE, CON ARMA DE FUEGO, USANDO M...
# 23                                 ROBO A MANO ARMADA
# 24                            ROBO AGRAVADO EN BANDA
# 25                         ASALTO Y ROBO DE VEHICULOS
# 26                                     ROBO AGRAVADO
# 27                                      ROBO AGRAVADO
# 28                                               ROBO
# 29                                      ROBO AGRAVADO

# %%
puntos = []
for index, row in df.iterrows():
    data = search_by_adress(row["LUGAR"] + " COMAS LIMA")
    if len(data["results"]):
      puntos.append(get_point_google_response(data["results"][0]))
    else:
      puntos.append("a")
df["GEOLOCALIZACION"] = puntos
df = df[df['GEOLOCALIZACION'] != "a"]
df = df.reset_index()
df
# Out:
#     index                                              LUGAR  SUMA_X  \
# 0      12  AV. BELAUNDE (CRUCE AV. EL RETABLO / AV. UNIVE...       3
# 1      13  AV. GUILLERMO LA FUENTE CDRAS. 1-3 (CRUCE AV. ...       4
# 2      14  AV TRAPICHE (CRUCE AV. CHACRA CERRO / AV. PANA...       6
# 3      17   AV  CARABAYLLO (AV 22 ADE AGOSTO - AV EL PARRAL)       8
# 4      18                     AV UNIVERSITARIA CON AV MEXICO       6
# 5      19  AV UNIVERSITARIA (JR LOPEZ ALDANA  - AV  METRO...      10
# 6      20                                       AV. BELAUNDE       6
# 7      21                                           AV. PUNO       5
# 8      22                                            MEGA 80       3
# 9      23      AV. BELAUNDE OESTE CUADRA 4 DISTRITO DE COMAS       2
# 10     24                  AV TUPAC AMARU FRENTE A PLAZA VEA       2
# 11     25                   JR CARLOS MORE NRO 602 AÑO NUEVO       2
# 12     26               PUENTE DEL PARADERO LA PASCANA COMAS       2
# 13     27  AV. REVOLUCION / AV. MARIA PARADO DE BELLIDO 5...       5
# 14     28  AV. REVOLUCION / AV. JULIO C. TELLO (MERCADO E...      11
# 15     29                     ALAMEDA YHONNY OROSCO 3RA ZONA       5
#
#                  TIPO DE DELITO  \
# 0                DCP ROBO/HURTO
# 1                DCP ROBO/HURTO
# 2                DCP ROBO/HURTO
# 3   DELITO CONTRA EL PATRIMONIO
# 4   DELITO CONTRA EL PATRIMONIO
# 5   DELITO CONTRA EL PATRIMONIO
# 6                         D/C/P
# 7                         D/C/P
# 8                         D/C/P
# 9   DELITO CONTRA EL PATRIMONIO
# 10  DELITO CONTRA EL PATRIMONIO
# 11  DELITO CONTRA EL PATRIMONIO
# 12  DELITO CONTRA EL PATRIMONIO
# 13                          DCP
# 14                          DCP
# 15                          DCP
#
#                                             MODALIDAD  \
# 0                         ARREBATO/SUSTRACCION/ARMADO
# 1                         ARREBATO/SUSTRACCION/ARMADO
# 2                         ARREBATO/SUSTRACCION/ARMADO
# 3                                       ROBO AGRAVADO
# 4                                       ROBO AGRAVADO
# 5                                       ROBO AGRAVADO
# 6   ROBO A TRANSEUNTE, CON ARMA DE FUEGO, USANDO M...
# 7   ROBO A TRANSEUNTE, CON ARMA DE FUEGO, USANDO M...
# 8   ROBO A TRANSEUNTE, CON ARMA DE FUEGO, USANDO M...
# 9                                  ROBO A MANO ARMADA
# 10                            ROBO AGRAVADO EN BANDA
# 11                         ASALTO Y ROBO DE VEHICULOS
# 12                                     ROBO AGRAVADO
# 13                                      ROBO AGRAVADO
# 14                                               ROBO
# 15                                      ROBO AGRAVADO
#
#                       GEOLOCALIZACION
# 0          (-11.9340488, -77.0564898)
# 1          (-11.9438598, -77.0583827)
# 2          (-11.9158392, -77.0606517)
# 3          (-11.9516408, -77.0555285)
# 4          (-11.9553406, -77.0596843)
# 5             (-11.94962, -77.060408)
# 6   (-11.9345735, -77.05701429999999)
# 7          (-11.9557704, -77.0431863)
# 8          (-11.9621224, -77.0550283)
# 9   (-11.9376528, -77.05295389999999)
# 10  (-11.9331579, -77.04557040000002)
# 11  (-11.9197837, -77.03731990000001)
# 12         (-11.9340672, -77.0469823)
# 13         (-11.9149667, -77.0305674)
# 14          (-11.9133767, -77.030125)
# 15           (-11.91846, -77.0269862)

# %%
data = search_by_adress("distrito de comas")
comas = data["results"][0]
m = Map(center=(get_point_google_response(comas)), zoom=13)
comasArea = make_circle(get_point_google_response(comas), "gray", 5350)
m.add_layer(comasArea)
colors = []
for index, row in df.iterrows():
    score = row["SUMA_X"]
    assigned_color = assign_color(score)
    colors.append(assigned_color)
    m.add_layer(make_circle(row["GEOLOCALIZACION"], assigned_color, 500))
df["COLOR"] = colors
df
# Out:
#     index                                              LUGAR  SUMA_X  \
# 0      12  AV. BELAUNDE (CRUCE AV. EL RETABLO / AV. UNIVE...       3
# 1      13  AV. GUILLERMO LA FUENTE CDRAS. 1-3 (CRUCE AV. ...       4
# 2      14  AV TRAPICHE (CRUCE AV. CHACRA CERRO / AV. PANA...       6
# 3      17   AV  CARABAYLLO (AV 22 ADE AGOSTO - AV EL PARRAL)       8
# 4      18                     AV UNIVERSITARIA CON AV MEXICO       6
# 5      19  AV UNIVERSITARIA (JR LOPEZ ALDANA  - AV  METRO...      10
# 6      20                                       AV. BELAUNDE       6
# 7      21                                           AV. PUNO       5
# 8      22                                            MEGA 80       3
# 9      23      AV. BELAUNDE OESTE CUADRA 4 DISTRITO DE COMAS       2
# 10     24                  AV TUPAC AMARU FRENTE A PLAZA VEA       2
# 11     25                   JR CARLOS MORE NRO 602 AÑO NUEVO       2
# 12     26               PUENTE DEL PARADERO LA PASCANA COMAS       2
# 13     27  AV. REVOLUCION / AV. MARIA PARADO DE BELLIDO 5...       5
# 14     28  AV. REVOLUCION / AV. JULIO C. TELLO (MERCADO E...      11
# 15     29                     ALAMEDA YHONNY OROSCO 3RA ZONA       5
#
#                  TIPO DE DELITO  \
# 0                DCP ROBO/HURTO
# 1                DCP ROBO/HURTO
# 2                DCP ROBO/HURTO
# 3   DELITO CONTRA EL PATRIMONIO
# 4   DELITO CONTRA EL PATRIMONIO
# 5   DELITO CONTRA EL PATRIMONIO
# 6                         D/C/P
# 7                         D/C/P
# 8                         D/C/P
# 9   DELITO CONTRA EL PATRIMONIO
# 10  DELITO CONTRA EL PATRIMONIO
# 11  DELITO CONTRA EL PATRIMONIO
# 12  DELITO CONTRA EL PATRIMONIO
# 13                          DCP
# 14                          DCP
# 15                          DCP
#
#                                             MODALIDAD  \
# 0                         ARREBATO/SUSTRACCION/ARMADO
# 1                         ARREBATO/SUSTRACCION/ARMADO
# 2                         ARREBATO/SUSTRACCION/ARMADO
# 3                                       ROBO AGRAVADO
# 4                                       ROBO AGRAVADO
# 5                                       ROBO AGRAVADO
# 6   ROBO A TRANSEUNTE, CON ARMA DE FUEGO, USANDO M...
# 7   ROBO A TRANSEUNTE, CON ARMA DE FUEGO, USANDO M...
# 8   ROBO A TRANSEUNTE, CON ARMA DE FUEGO, USANDO M...
# 9                                  ROBO A MANO ARMADA
# 10                            ROBO AGRAVADO EN BANDA
# 11                         ASALTO Y ROBO DE VEHICULOS
# 12                                     ROBO AGRAVADO
# 13                                      ROBO AGRAVADO
# 14                                               ROBO
# 15                                      ROBO AGRAVADO
#
#                       GEOLOCALIZACION   COLOR
# 0          (-11.9340488, -77.0564898)  orange
# 1          (-11.9438598, -77.0583827)  orange
# 2          (-11.9158392, -77.0606517)     red
# 3          (-11.9516408, -77.0555285)     red
# 4          (-11.9553406, -77.0596843)     red
# 5             (-11.94962, -77.060408)     red
# 6   (-11.9345735, -77.05701429999999)     red
# 7          (-11.9557704, -77.0431863)     red
# 8          (-11.9621224, -77.0550283)  orange
# 9   (-11.9376528, -77.05295389999999)  yellow
# 10  (-11.9331579, -77.04557040000002)  yellow
# 11  (-11.9197837, -77.03731990000001)  yellow
# 12         (-11.9340672, -77.0469823)  yellow
# 13         (-11.9149667, -77.0305674)     red
# 14          (-11.9133767, -77.030125)     red
# 15           (-11.91846, -77.0269862)     red

# %%
m
# Out:
# Map(center=[-11.9150865, -77.04784819999999], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom…

# %%
# save in sqlite
import sqlite3
conn = sqlite3.connect('knn.db')
df["GEOLOCALIZACION"] = df["GEOLOCALIZACION"].astype(str)
df
df.to_sql('puntos', conn, if_exists='replace', index=False)
# Out:
# 16
